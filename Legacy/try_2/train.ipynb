# %%
import os
import time
import shutil
import numpy as np
import tensorflow as tf
import core.utils as utils
from tqdm import tqdm
from core.dataset2 import Dataset
from core.yolov3 import YOLOv3, decode, compute_loss
from core.config2 import cfg

# %%
trainset = Dataset('train')
validset = Dataset("val")

logdir = "./data/log/try1/"

train_steps_per_epoch = len(trainset) # traindataset step 개수 24186 // Batch_size
valid_steps_per_epoch = len(validset)

global_steps = tf.Variable(1, trainable=False, dtype=tf.int64)
warmup_steps = cfg.TRAIN.WARMUP_EPOCHS * train_steps_per_epoch
total_steps = cfg.TRAIN.EPOCHS * train_steps_per_epoch

input_tensor = tf.keras.layers.Input([416, 416, 3])
conv_tensors = YOLOv3(input_tensor)

output_tensors = []
for i, conv_tensor in enumerate(conv_tensors):
    pred_tensor = decode(conv_tensor, i)
    output_tensors.append(conv_tensor)
    output_tensors.append(pred_tensor)

model = tf.keras.Model(input_tensor, output_tensors)
model.load_weights("./yolov3")
optimizer = tf.keras.optimizers.Adam()
if os.path.exists(logdir): shutil.rmtree(logdir)
writer = tf.summary.create_file_writer(logdir)

def train_step(image_data, target):
    with tf.GradientTape() as tape:
        pred_result = model(image_data, training=True)
        giou_loss=conf_loss=prob_loss=0

        # optimizing process
        for i in range(3):
            conv, pred = pred_result[i*2], pred_result[i*2+1]
            loss_items = compute_loss(pred, conv, *target[i], i)
            giou_loss += loss_items[0]
            conf_loss += loss_items[1]
            prob_loss += loss_items[2]

        total_loss = giou_loss + conf_loss + prob_loss

        gradients = tape.gradient(total_loss, model.trainable_variables)
        optimizer.apply_gradients(zip(gradients, model.trainable_variables))
        if global_steps % 200==1:
            tf.print(
                f"| Step: %.5d\t| \
                Epochs: %.2d /%.2d\t| \
                lr: %.6f\t| \
                Giou_Loss: %.3f\t| \
                Conf_Loss: %.3f\t| \
                Prob_Loss: %.3f\t| \
                Total_Loss: %.3f \t|\
                "%(global_steps,epoch,cfg.TRAIN.EPOCHS,optimizer.lr.numpy(),giou_loss,conf_loss,prob_loss,total_loss)
            )

        
        # update learning rate
        global_steps.assign_add(1)
        if global_steps < warmup_steps:
            lr = global_steps / warmup_steps *cfg.TRAIN.LR_INIT
        else:
            lr = cfg.TRAIN.LR_END + 0.5 * (cfg.TRAIN.LR_INIT - cfg.TRAIN.LR_END) * (
                (1 + tf.cos((global_steps - warmup_steps) / (total_steps - warmup_steps) * np.pi))
            )
        optimizer.lr.assign(lr.numpy())

        # writing summary data
        with writer.as_default():
            tf.summary.scalar("lr", optimizer.lr, step=global_steps)
            tf.summary.scalar("train_loss/total_loss", total_loss, step=global_steps)
            tf.summary.scalar("train_loss/giou_loss", giou_loss, step=global_steps)
            tf.summary.scalar("train_loss/conf_loss", conf_loss, step=global_steps)
            tf.summary.scalar("train_loss/prob_loss", prob_loss, step=global_steps)
        writer.flush()

def val_step(validset):
    giou_loss=conf_loss=prob_loss=0
    
    for image_data, target in validset:
        pred_result = model(image_data, training=False)
        
        # optimizing process
        for i in range(3):
            conv, pred = pred_result[i*2], pred_result[i*2+1]
            loss_items = compute_loss(pred, conv, *target[i], i)
            giou_loss += loss_items[0]
            conf_loss += loss_items[1]
            prob_loss += loss_items[2]

        total_loss = giou_loss + conf_loss + prob_loss
    
    giou_loss = giou_loss / valid_steps_per_epoch
    conf_loss = conf_loss / valid_steps_per_epoch
    prob_loss = prob_loss / valid_steps_per_epoch
    total_loss = total_loss / valid_steps_per_epoch
    
    tf.print(
        f"| Epochs: %.2d /%.2d\t| \
        Giou_Loss: %4.2f\t| \
        Conf_Loss: %4.2f\t| \
        Prob_Loss: %4.2f\t| \
        Total_Loss: %4.2f \t|\
        "%(epoch,cfg.TRAIN.EPOCHS,giou_loss,conf_loss,prob_loss,total_loss)
    )

    # writing summary data
    with writer.as_default():
        tf.summary.scalar("valid_loss/total_loss", total_loss, step=epoch)
        tf.summary.scalar("valid_loss/giou_loss", giou_loss, step=epoch)
        tf.summary.scalar("valid_loss/conf_loss", conf_loss, step=epoch)
        tf.summary.scalar("valid_loss/prob_loss", prob_loss, step=epoch)
    writer.flush()        
        

for epoch in range(cfg.TRAIN.EPOCHS):
    for image_data, target in trainset:
        train_step(image_data, target)
    valid_step(validset)
    model.save_weights("./yolov3")
# http://localhost:6006/
# Out:
# C:\Users\rh987\AppData\Roaming\Python\Python39\site-packages\albumentations\imgaug\transforms.py:346: FutureWarning: This IAAAffine is deprecated. Please use Affine instead
#   warnings.warn("This IAAAffine is deprecated. Please use Affine instead", FutureWarning)
# | Step: 00001	|                 Epochs: 00 /10	|                 lr: 0.001000	|                 Giou_Loss: 66.562	|                 Conf_Loss: 56.302	|                 Prob_Loss: 37.774	|                 Total_Loss: 160.638 	|
# | Step: 00201	|                 Epochs: 00 /10	|                 lr: 0.000017	|                 Giou_Loss: 32.954	|                 Conf_Loss: 47.737	|                 Prob_Loss: 21.674	|                 Total_Loss: 102.364 	|
# | Step: 00401	|                 Epochs: 00 /10	|                 lr: 0.000033	|                 Giou_Loss: 25.494	|                 Conf_Loss: 31.810	|                 Prob_Loss: 21.136	|                 Total_Loss: 78.440 	|
# error []
# | Step: 00601	|                 Epochs: 00 /10	|                 lr: 0.000050	|                 Giou_Loss: 56.350	|                 Conf_Loss: 48.231	|                 Prob_Loss: 35.998	|                 Total_Loss: 140.579 	|
# | Step: 00801	|                 Epochs: 00 /10	|                 lr: 0.000066	|                 Giou_Loss: 21.517	|                 Conf_Loss: 24.342	|                 Prob_Loss: 5.217	|                 Total_Loss: 51.076 	|
# error []
# | Step: 01001	|                 Epochs: 00 /10	|                 lr: 0.000083	|                 Giou_Loss: 58.595	|                 Conf_Loss: 48.441	|                 Prob_Loss: 18.804	|                 Total_Loss: 125.840 	|
# error []
# | Step: 01201	|                 Epochs: 00 /10	|                 lr: 0.000100	|                 Giou_Loss: 22.095	|                 Conf_Loss: 29.970	|                 Prob_Loss: 8.812	|                 Total_Loss: 60.877 	|
# | Step: 01401	|                 Epochs: 00 /10	|                 lr: 0.000116	|                 Giou_Loss: 77.778	|                 Conf_Loss: 93.052	|                 Prob_Loss: 37.328	|                 Total_Loss: 208.158 	|
# | Step: 04801	|                 Epochs: 00 /10	|                 lr: 0.000398	|                 Giou_Loss: 41.693	|                 Conf_Loss: 56.428	|                 Prob_Loss: 16.137	|                 Total_Loss: 114.257 	|
# | Step: 05001	|                 Epochs: 00 /10	|                 lr: 0.000415	|                 Giou_Loss: 40.451	|                 Conf_Loss: 48.402	|                 Prob_Loss: 13.124	|                 Total_Loss: 101.978 	|
# | Step: 05201	|                 Epochs: 00 /10	|                 lr: 0.000432	|                 Giou_Loss: 30.677	|                 Conf_Loss: 24.319	|                 Prob_Loss: 13.675	|                 Total_Loss: 68.670 	|
# | Step: 05401	|                 Epochs: 00 /10	|                 lr: 0.000448	|                 Giou_Loss: 43.776	|                 Conf_Loss: 37.966	|                 Prob_Loss: 27.220	|                 Total_Loss: 108.963 	|
# | Step: 05601	|                 Epochs: 00 /10	|                 lr: 0.000465	|                 Giou_Loss: 28.447	|                 Conf_Loss: 33.962	|                 Prob_Loss: 7.573	|                 Total_Loss: 69.982 	|
# | Step: 05801	|                 Epochs: 00 /10	|                 lr: 0.000481	|                 Giou_Loss: 77.562	|                 Conf_Loss: 60.450	|                 Prob_Loss: 28.738	|                 Total_Loss: 166.750 	|
# | Step: 06001	|                 Epochs: 00 /10	|                 lr: 0.000498	|                 Giou_Loss: 22.792	|                 Conf_Loss: 32.910	|                 Prob_Loss: 3.520	|                 Total_Loss: 59.222 	|
# | Step: 06201	|                 Epochs: 00 /10	|                 lr: 0.000515	|                 Giou_Loss: 45.586	|                 Conf_Loss: 54.807	|                 Prob_Loss: 19.333	|                 Total_Loss: 119.726 	|
# | Step: 06401	|                 Epochs: 00 /10	|                 lr: 0.000531	|                 Giou_Loss: nan	|                 Conf_Loss: 33.294	|                 Prob_Loss: 5.751	|                 Total_Loss: nan 	|
# | Step: 06601	|                 Epochs: 00 /10	|                 lr: 0.000548	|                 Giou_Loss: nan	|                 Conf_Loss: nan	|                 Prob_Loss: nan	|                 Total_Loss: nan 	|
# | Step: 06801	|                 Epochs: 00 /10	|                 lr: 0.000564	|                 Giou_Loss: nan	|                 Conf_Loss: nan	|                 Prob_Loss: nan	|                 Total_Loss: nan 	|
# | Step: 07001	|                 Epochs: 00 /10	|                 lr: 0.000581	|                 Giou_Loss: nan	|                 Conf_Loss: nan	|                 Prob_Loss: nan	|                 Total_Loss: nan 	|
# | Step: 07201	|                 Epochs: 00 /10	|                 lr: 0.000598	|                 Giou_Loss: nan	|                 Conf_Loss: nan	|                 Prob_Loss: nan	|                 Total_Loss: nan 	|
# | Step: 07401	|                 Epochs: 00 /10	|                 lr: 0.000614	|                 Giou_Loss: nan	|                 Conf_Loss: nan	|                 Prob_Loss: nan	|                 Total_Loss: nan 	|
# | Step: 07601	|                 Epochs: 00 /10	|                 lr: 0.000631	|                 Giou_Loss: nan	|                 Conf_Loss: nan	|                 Prob_Loss: nan	|                 Total_Loss: nan 	|
# | Step: 07801	|                 Epochs: 00 /10	|                 lr: 0.000647	|                 Giou_Loss: nan	|                 Conf_Loss: nan	|                 Prob_Loss: nan	|                 Total_Loss: nan 	|
# | Step: 08001	|                 Epochs: 00 /10	|                 lr: 0.000664	|                 Giou_Loss: nan	|                 Conf_Loss: nan	|                 Prob_Loss: nan	|                 Total_Loss: nan 	|
# error []
# | Step: 08201	|                 Epochs: 00 /10	|                 lr: 0.000681	|                 Giou_Loss: nan	|                 Conf_Loss: nan	|                 Prob_Loss: nan	|                 Total_Loss: nan 	|
# | Step: 08401	|                 Epochs: 00 /10	|                 lr: 0.000697	|                 Giou_Loss: nan	|                 Conf_Loss: nan	|                 Prob_Loss: nan	|                 Total_Loss: nan 	|
# error []
# | Step: 08601	|                 Epochs: 00 /10	|                 lr: 0.000714	|                 Giou_Loss: nan	|                 Conf_Loss: nan	|                 Prob_Loss: nan	|                 Total_Loss: nan 	|
# error []
# | Step: 08801	|                 Epochs: 00 /10	|                 lr: 0.000730	|                 Giou_Loss: nan	|                 Conf_Loss: nan	|                 Prob_Loss: nan	|                 Total_Loss: nan 	|
# | Step: 09001	|                 Epochs: 00 /10	|                 lr: 0.000747	|                 Giou_Loss: nan	|                 Conf_Loss: nan	|                 Prob_Loss: nan	|                 Total_Loss: nan 	|
# error []
# | Step: 09201	|                 Epochs: 00 /10	|                 lr: 0.000764	|                 Giou_Loss: nan	|                 Conf_Loss: nan	|                 Prob_Loss: nan	|                 Total_Loss: nan 	|
# | Step: 09401	|                 Epochs: 00 /10	|                 lr: 0.000780	|                 Giou_Loss: nan	|                 Conf_Loss: nan	|                 Prob_Loss: nan	|                 Total_Loss: nan 	|
# | Step: 09601	|                 Epochs: 00 /10	|                 lr: 0.000797	|                 Giou_Loss: nan	|                 Conf_Loss: nan	|                 Prob_Loss: nan	|                 Total_Loss: nan 	|
# | Step: 09801	|                 Epochs: 00 /10	|                 lr: 0.000813	|                 Giou_Loss: nan	|                 Conf_Loss: nan	|                 Prob_Loss: nan	|                 Total_Loss: nan 	|
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 117
#     113     writer.flush()
#     116 for epoch in range(cfg.TRAIN.EPOCHS):
# --> 117     for image_data, target in trainset:
#     118         train_step(image_data, target)
#     119     valid_step(validset)
#
# File c:\Users\rh987\OneDrive\document\GitHub\SIA-MOT\try2\core\dataset2.py:111, in Dataset.__next__(self)
#     109 if index >= self.num_samples: index -= self.num_samples
#     110 annotation = self.annotations[index]
# --> 111 image, bboxes = self.parse_annotation(annotation)
#     112 label_sbbox, label_mbbox, label_lbbox, sbboxes, mbboxes, lbboxes = self.preprocess_true_boxes(bboxes)
#     114 batch_image[num, :, :, :] = image
#
# File c:\Users\rh987\OneDrive\document\GitHub\SIA-MOT\try2\core\dataset2.py:142, in Dataset.parse_annotation(self, annotation)
#     139 if not os.path.exists(image_path):
#     140     raise KeyError("%s does not exist ... " %image_path)
# --> 142 image = cv2.cvtColor(cv2.imread(image_path),cv2.COLOR_BGR2RGB)
#     144 bboxes = np.array([list(map(int, box.split(','))) for box in line[1:]])
#     146 aug_data = self.transform(image=image,bboxes=bboxes)
#
# KeyboardInterrupt:

# %%
model.save_weights("./yolov3_try2")

# %%
# !tensorboard --logdir ./data/log
# Out:
# ^C

# %%
for epoch in range(1): #cfg.TRAIN.EPOCHS
#     for image_data, target in trainset:
#         train_step(image_data, target)
    val_step(validset)
    # model.save_weights("./yolov3")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 for epoch in range(1): #cfg.TRAIN.EPOCHS
#       2 #     for image_data, target in trainset:
#       3 #         train_step(image_data, target)
# ----> 4     val_step(validset)
#
# Cell In[2], line 86, in val_step(validset)
#      84 for i in range(3):
#      85     conv, pred = pred_result[i*2], pred_result[i*2+1]
# ---> 86     loss_items = compute_loss(pred, conv, *target[i], i)
#      87     giou_loss += loss_items[0]
#      88     conf_loss += loss_items[1]
#
# File c:\Users\rh987\OneDrive\document\GitHub\SIA-MOT\try2\core\yolov3.py:158, in compute_loss(pred, conv, label, bboxes, i)
#     155 respond_bbox  = label[:, :, :, :, 4:5]
#     156 label_prob    = label[:, :, :, :, 5:]
# --> 158 giou = tf.expand_dims(bbox_giou(pred_xywh, label_xywh), axis=-1)
#     159 input_size = tf.cast(input_size, tf.float32)
#     161 bbox_loss_scale = 2.0 - 1.0 * label_xywh[:, :, :, :, 2:3] * label_xywh[:, :, :, :, 3:4] / (input_size ** 2)
#
# File c:\Users\rh987\OneDrive\document\GitHub\SIA-MOT\try2\core\yolov3.py:117, in bbox_giou(boxes1, boxes2)
#     112 boxes2 = tf.concat([boxes2[..., :2] - boxes2[..., 2:] * 0.5,
#     113                     boxes2[..., :2] + boxes2[..., 2:] * 0.5], axis=-1)
#     115 boxes1 = tf.concat([tf.minimum(boxes1[..., :2], boxes1[..., 2:]),
#     116                     tf.maximum(boxes1[..., :2], boxes1[..., 2:])], axis=-1)
# --> 117 boxes2 = tf.concat([tf.minimum(boxes2[..., :2], boxes2[..., 2:]),
#     118                     tf.maximum(boxes2[..., :2], boxes2[..., 2:])], axis=-1)
#     120 boxes1_area = (boxes1[..., 2] - boxes1[..., 0]) * (boxes1[..., 3] - boxes1[..., 1])
#     121 boxes2_area = (boxes2[..., 2] - boxes2[..., 0]) * (boxes2[..., 3] - boxes2[..., 1])
#
# File c:\Users\rh987\anaconda3\envs\tf\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\rh987\anaconda3\envs\tf\lib\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\rh987\anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\array_ops.py:1096, in _slice_helper(tensor, slice_spec, var)
#    1094   var_empty = constant([], dtype=dtypes.int32)
#    1095   packed_begin = packed_end = packed_strides = var_empty
# -> 1096 return strided_slice(
#    1097     tensor,
#    1098     packed_begin,
#    1099     packed_end,
#    1100     packed_strides,
#    1101     begin_mask=begin_mask,
#    1102     end_mask=end_mask,
#    1103     shrink_axis_mask=shrink_axis_mask,
#    1104     new_axis_mask=new_axis_mask,
#    1105     ellipsis_mask=ellipsis_mask,
#    1106     var=var,
#    1107     name=name)
#
# File c:\Users\rh987\anaconda3\envs\tf\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\rh987\anaconda3\envs\tf\lib\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\rh987\anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\array_ops.py:1269, in strided_slice(input_, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, var, name)
#    1266 if strides is None:
#    1267   strides = ones_like(begin)
# -> 1269 op = gen_array_ops.strided_slice(
#    1270     input=input_,
#    1271     begin=begin,
#    1272     end=end,
#    1273     strides=strides,
#    1274     name=name,
#    1275     begin_mask=begin_mask,
#    1276     end_mask=end_mask,
#    1277     ellipsis_mask=ellipsis_mask,
#    1278     new_axis_mask=new_axis_mask,
#    1279     shrink_axis_mask=shrink_axis_mask)
#    1281 parent_name = name
#    1283 if var is not None:
#
# File c:\Users\rh987\anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\gen_array_ops.py:10671, in strided_slice(input, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, name)
#   10669 if tld.is_eager:
#   10670   try:
# > 10671     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#   10672       _ctx, "StridedSlice", name, input, begin, end, strides, "begin_mask",
#   10673       begin_mask, "end_mask", end_mask, "ellipsis_mask", ellipsis_mask,
#   10674       "new_axis_mask", new_axis_mask, "shrink_axis_mask", shrink_axis_mask)
#   10675     return _result
#   10676   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# # Test

# %%
import cv2
import os
import shutil
import numpy as np
import tensorflow as tf
import core.utils as utils
from core.config import cfg
from core.yolov3 import YOLOv3, decode

# %%
INPUT_SIZE   = 416
NUM_CLASS    = len(utils.read_class_names(cfg.YOLO.CLASSES))
CLASSES      = utils.read_class_names(cfg.YOLO.CLASSES)

predicted_dir_path = './predicted'
ground_truth_dir_path = './ground-truth'
if os.path.exists(predicted_dir_path): shutil.rmtree(predicted_dir_path)
if os.path.exists(ground_truth_dir_path): shutil.rmtree(ground_truth_dir_path)
if os.path.exists(cfg.TEST.DECTECTED_IMAGE_PATH): shutil.rmtree(cfg.TEST.DECTECTED_IMAGE_PATH)

os.mkdir(predicted_dir_path)
os.mkdir(ground_truth_dir_path)
os.mkdir(cfg.TEST.DECTECTED_IMAGE_PATH)

# Build Model
input_layer  = tf.keras.layers.Input([INPUT_SIZE, INPUT_SIZE, 3])
feature_maps = YOLOv3(input_layer)

bbox_tensors = []
for i, fm in enumerate(feature_maps):
    bbox_tensor = decode(fm, i)
    bbox_tensors.append(bbox_tensor)

model = tf.keras.Model(input_layer, bbox_tensors)
model.load_weights("./yolov3_try2")

with open(cfg.TEST.ANNOT_PATH, 'r') as annotation_file:
    for num, line in enumerate(annotation_file):
        annotation = line.strip().split()
        image_path = annotation[0]
        image_name = "/".join(image_path.split('/')[-2:])
        image = cv2.imread(image_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        bbox_data_gt = np.array([list(map(int, box.split(','))) for box in annotation[1:]])

        if len(bbox_data_gt) == 0:
            bboxes_gt=[]
            classes_gt=[]
        else:
            bboxes_gt, classes_gt = bbox_data_gt[:, :4], bbox_data_gt[:, 4]
        ground_truth_path = os.path.join(ground_truth_dir_path, str(num) + '.txt')

        print('=> ground truth of %s:' % image_name)
        num_bbox_gt = len(bboxes_gt)
        with open(ground_truth_path, 'w') as f:
            for i in range(num_bbox_gt):
                class_name = CLASSES[classes_gt[i]]
                xmin, ymin, xmax, ymax = list(map(str, bboxes_gt[i]))
                bbox_mess = ' '.join([class_name, xmin, ymin, xmax, ymax]) + '\n'
                f.write(bbox_mess)
                print('\t' + str(bbox_mess).strip())
        print('=> predict result of %s:' % image_name)
        predict_result_path = os.path.join(predicted_dir_path, str(num) + '.txt')
        # Predict Process
        image_size = image.shape[:2]
        image_data = utils.image_preporcess(np.copy(image), [INPUT_SIZE, INPUT_SIZE])
        image_data = image_data[np.newaxis, ...].astype(np.float32)

        pred_bbox = model.predict(image_data)
        pred_bbox = [tf.reshape(x, (-1, tf.shape(x)[-1])) for x in pred_bbox]
        pred_bbox = tf.concat(pred_bbox, axis=0)
        bboxes = utils.postprocess_boxes(pred_bbox, image_size, INPUT_SIZE, cfg.TEST.SCORE_THRESHOLD)
        bboxes = utils.nms(bboxes, cfg.TEST.IOU_THRESHOLD, method='nms')


        if cfg.TEST.DECTECTED_IMAGE_PATH is not None:
            image = utils.draw_bbox(image, bboxes)
            cv2.imwrite(cfg.TEST.DECTECTED_IMAGE_PATH+image_name, image)

        with open(predict_result_path, 'w') as f:
            for bbox in bboxes:
                coor = np.array(bbox[:4], dtype=np.int32)
                score = bbox[4]
                class_ind = int(bbox[5])
                class_name = CLASSES[class_ind]
                score = '%.4f' % score
                xmin, ymin, xmax, ymax = list(map(str, coor))
                bbox_mess = ' '.join([class_name, score, xmin, ymin, xmax, ymax]) + '\n'
                f.write(bbox_mess)
                print('\t' + str(bbox_mess).strip())
        f.close()
# Out:
# => ground truth of visdrone/VisDrone2019-MOT-test\sequences\uav0000009_03358_v\uav0000009_03358_v_0000001.jpg:
# 	car 130 672 303 760
# 	car 178 600 333 665
# 	car 317 272 418 331
# 	car 338 231 447 277
# 	car 363 193 461 241
# 	car 774 262 883 333
# 	car 765 216 863 281
# 	car 754 182 856 244
# 	car 1048 591 1176 682
# 	car 1022 510 1156 596
# 	car 1278 280 1359 348
# 	car 1243 186 1347 245
# 	people 344 295 366 332
# 	car 1202 120 1299 180
# 	car 1184 97 1277 140
# => predict result of visdrone/VisDrone2019-MOT-test\sequences\uav0000009_03358_v\uav0000009_03358_v_0